# %%
pip install pandas numpy gensim matplotlib nltk
# Out:
# Requirement already satisfied: pandas in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.26.4)
# Requirement already satisfied: gensim in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.3.3)
# Requirement already satisfied: matplotlib in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: nltk in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gensim) (7.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: click in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: six>=1.5 in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: wrapt in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: colorama in c:\users\juan-\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import nltk
import os
import gensim
from gensim.models import Word2Vec
from scipy.spatial.distance import cosine
import matplotlib.pyplot as plt

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# Your code here

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\juan-\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Load the CSV file
df = pd.read_csv(
    r'C:\Users\juan-\Documents\Proyecto Hacku AI\Repositorio GitHub página\proyecto_integrador_equipo_27\Avance4.27\Word2vec\HS code Catalogue_Processed (web scrapped).csv',
    dtype={'HTS code': str}  # Specify the column to be read as string
)
# Rename columns for easier access
df.rename(columns={'HS Code': 'HTS_code', 'Full description': 'Description'}, inplace=True)

# Preprocess descriptions (remove punctuation, convert to lower case)
df['processed_description'] = df['Description'].str.replace(r'[^\w\s]', '', regex=True).str.lower()

# Handle NaN values
df = df.dropna(subset=['HTS_code', 'processed_description'])

# Convert HTS_code to string and remove periods
df['HTS_code'] = df['HTS_code'].str.replace('.', '', regex=False)

# Trim HTS codes to the leftmost 6 characters and pad with trailing zeros if shorter
df['HTS_code'] = df['HTS_code'].apply(lambda x: x[:6].ljust(6, '0'))

# Create a text file for unsupervised training, where each line is a processed description
unsupervised_file_path = 'unsupervised_training_data.txt'
df['processed_description'].to_csv(unsupervised_file_path, index=False, header=False)

df.head(100)
# Out:
#    HTS_code                                        Description  \
# 0    010000                           Chapter 1   Live animals
# 1    010100             Live horses, asses, mules and hinnies.
# 2    010121  Live horses, asses, mules and hinnies. - > Hor...
# 3    010129  Live horses, asses, mules and hinnies. - > Hor...
# 4    010130   Live horses, asses, mules and hinnies. -> Asses:
# ..      ...                                                ...
# 95   020500  Meat of horses, asses, mules or hinnies, fresh...
# 96   020600  Edible offal of bovine animals, swine, sheep, ...
# 97   020610  Edible offal of bovine animals, swine, sheep, ...
# 98   020621  Edible offal of bovine animals, swine, sheep, ...
# 99   020622  Edible offal of bovine animals, swine, sheep, ...
#
#                                 processed_description
# 0                            chapter 1   live animals
# 1                 live horses asses mules and hinnies
# 2   live horses asses mules and hinnies   horses  ...
# 3   live horses asses mules and hinnies   horses  ...
# 4          live horses asses mules and hinnies  asses
# ..                                                ...
# 95  meat of horses asses mules or hinnies fresh ch...
# 96  edible offal of bovine animals swine sheep goa...
# 97  edible offal of bovine animals swine sheep goa...
# 98  edible offal of bovine animals swine sheep goa...
# 99  edible offal of bovine animals swine sheep goa...
#
# [100 rows x 3 columns]

# %%
# Placeholder for your pre-trained Word2Vec embeddings file
word2vec_path = r'C:\Users\juan-\Documents\Proyecto Hacku AI\Repositorio GitHub página\proyecto_integrador_equipo_27\Avance4.27\Word2vec\GoogleNews-vectors-negative300.bin'  # Replace with the actual path

# %%
import gensim.downloader as api

# Download the pre-trained Word2Vec model
#w2v_model = api.load("word2vec-google-news-300")  # This downloads and loads the Google News model

# Check if the model is loaded correctly
#print("Loaded Word2Vec model with vocabulary size:", len(w2v_model.key_to_index))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       1 import gensim.downloader as api
#       3 # Download the pre-trained Word2Vec model
#       4 #w2v_model = api.load("word2vec-google-news-300")  # This downloads and loads the Google News model
#       5
#       6 # Check if the model is loaded correctly
# ----> 7 print("Loaded Word2Vec model with vocabulary size:", len(w2v_model.key_to_index))
#
# NameError: name 'w2v_model' is not defined

# %%
# Load the Word2Vec model
w2v_model = gensim.models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)

# Check if the model is loaded correctly using the new attribute
print("Loaded Word2Vec model with vocabulary size:", len(w2v_model.key_to_index))
# Out:
# Loaded Word2Vec model with vocabulary size: 3000000

# %%
# Tokenize the descriptions for Word2Vec training
df['tokenized_descriptions'] = df['processed_description'].apply(nltk.word_tokenize)

# Train the Word2Vec model using the tokenized descriptions
fine_tuned_model = Word2Vec(sentences=df['tokenized_descriptions'], vector_size=300, window=5, min_count=1, workers=4)

# Save the fine-tuned model for later use
fine_tuned_model.save('fine_tuned_word2vec.model')

# Check if training was successful
print("Fine-tuned Word2Vec model trained on your data.")
# Out:
# Fine-tuned Word2Vec model trained on your data.

# %%
def vectorize_description(description):
    words = description.split()
    word_vectors = [fine_tuned_model.wv[word] for word in words if word in fine_tuned_model.wv]
    if not word_vectors:
        return np.zeros(fine_tuned_model.vector_size)  # Return a zero vector if no words are found
    return np.mean(word_vectors, axis=0)

# Vectorize each description in the DataFrame
df['description_vector'] = df['processed_description'].apply(vectorize_description)

# Check the vectors for the first few descriptions
print(df[['Description', 'description_vector']].head())
# Out:
#                                          Description  \
# 0                           Chapter 1   Live animals
# 1             Live horses, asses, mules and hinnies.
# 2  Live horses, asses, mules and hinnies. - > Hor...
# 3  Live horses, asses, mules and hinnies. - > Hor...
# 4   Live horses, asses, mules and hinnies. -> Asses:
#
#                                   description_vector
# 0  [-0.49040705, 0.11235659, -0.091928884, 0.6467...
# 1  [-0.15271406, -0.08248513, 0.0012492972, 0.198...
# 2  [-0.18331881, -0.028035255, -0.009673842, 0.24...
# 3  [-0.14488767, -0.090664, -0.03016447, 0.204923...
# 4  [-0.16007555, -0.06908799, 0.0034828528, 0.198...

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def predict_hs_code(input_description):
    # Ensure the vectorize_description returns a 1D vector
    input_vector = vectorize_description(input_description)
    
    # Convert the description vectors from the dataframe to a 2D array
    description_vectors = np.vstack(df['description_vector'].values)
    
    # Calculate cosine similarities between the input vector and all description vectors
    similarities = cosine_similarity([input_vector], description_vectors)
    
    # Get the index of the most similar description
    most_similar_index = np.argmax(similarities)
    
    # Return the corresponding HTS code
    return df.iloc[most_similar_index]['HTS_code']

# Example usage
input_desc = "ventanas de madera y accessorios"
predicted_code = predict_hs_code(input_desc)
print(f"Predicted HTS Code: {predicted_code}")
# Out:
# Predicted HTS Code: 283410

# %%
validation_df = pd.read_csv(
    r'C:\Users\juan-\Documents\Proyecto Hacku AI\Repositorio GitHub página\proyecto_integrador_equipo_27\Avance4.27\data validation verified.csv',
    dtype={'HTS code': str}  # Specify the column to be read as string
)

validation_df
# Out:
#                                         Raw_data_input  \
# 0    CERAMIC TABLEWARE 26 PALL ETS 192 BOXES 2688 B...
# 1    TOTAL 5040 BOXES ONLY TOTA L FIVE THOUSAND FOU...
# 2    FREE-CUTTING STEELS COLD DRAWN SPECIFICATION C...
# 3    PAPER FOR CORES K 05 HS CODE48239085 NCM CODES...
# 4    CIGARETTES SO 10217102461021742687 HS CODE 240...
# ..                                                 ...
# 215   SHOWCAR 1999 FERRARI F399 - VIN26 HS CODE8703.23
# 216    STEEL BARS HS CODE 72283061  NCM CODES 72283061
# 217  CERAMIC TILES AND SAMPLES HS CODE 690721 18 PA...
# 218  1X20DC. SAID TO CONTAIN 20 PAL TANNING EXTRACT...
# 219  CHAIR PARTS  HS CODE 9401 9080 3916 9050NCM CO...
#
#                               Raw_data_input_processed LLM_prediction  \
# 0                  ceramic tableware pall ets box boxe           6910
# 1    total box tota l five thousand fourty box tota...           6915
# 2       freecutting steel cold drawn specification clc           7213
# 3                                           paper core     4811.10.00
# 4                                            cigarette           2401
# ..                                                 ...            ...
# 215                                showcar ferrari vin     8701.10.00
# 216                                          steel bar           7213
# 217                                ceramic tile sample           6915
# 218  said contain pal tanning extract dyeing extrac...           3204
# 219                                              chair           9401
#
#      Expected_output  Expected_output_two_digits  Expected_output_four_digits
# 0               6912                          69                         6912
# 1            6907210                          69                         6907
# 2           72151000                          72                         7215
# 3           48239085                          48                         4823
# 4               2402                          24                         2402
# ..               ...                         ...                          ...
# 215             8703                          87                         8703
# 216         72283061                          72                         7228
# 217           690721                          69                         6907
# 218         32041610                          32                         3204
# 219             9401                          94                         9401
#
# [220 rows x 6 columns]

# %%
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer, BertTokenizer, BertModel
import nltk
from nltk.corpus import words, stopwords
from nltk.stem import WordNetLemmatizer
import string
import re
import torch
from collections import Counter

# Download necessary NLTK data
nltk.download('words')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Load the translation model (use Spanish-to-English model)
model_name = 'Helsinki-NLP/opus-mt-es-en'  # Spanish to English model
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Load BERT model for attention scoring
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')

# Get the English words corpus and Spanish stopwords
english_words = set(words.words())
spanish_stopwords = set(stopwords.words('spanish'))
english_stopwords = set(stopwords.words('english'))

# Add your custom stopwords to the Spanish stopwords
additional_stopwords = {
    'abv', 'accessories', 'aduana', 'agent', 'ancho', 'approximately', 'approx', 'ata', 'atd', 'attn', 'attention',
    'awb', 'b', 'bag', 'bags', 'barge', 'batch', 'big', 'bill', 'bl', 'bol', 'bonded', 'bottle', 'bottles',
    'box', 'boxes', 'broker', 'bulk', 'bundle', 'bundles', 'cargo', 'carrier', 'carton', 'cartons', 'case', 'cases',
    'cb', 'cbm', 'celsius', 'center', 'certificate', 'certification', 'cfr', 'charge', 'charges', 'cif', 'cip', 'circa',
    'claim', 'class', 'classification', 'clearance', 'cl', 'closing', 'cm', 'cmr', 'cntr', 'code', 'codes', 'collect',
    'collection', 'commercial', 'commodity', 'consolidated', 'consolidator', 'consignee', 'consignor', 'contain',
    'container', 'containers', 'containing', 'contains', 'contact', 'coo', 'cross', 'ctr', 'ctpat', 'cube', 'cubic',
    'customs', 'cut-off', 'damage', 'dangerous', 'dap', 'date', 'dated', 'dc', 'ddp', 'deadline', 'declared',
    'declares', 'declaration', 'degr', 'degrees', 'delay', 'delivery', 'demurrage', 'description', 'destination',
    'detention', 'dg', 'diameter', 'dim', 'dimension', 'dimensions', 'discharge', 'distribution', 'dock',
    'documentation', 'dt', 'dtd', 'duty', 'each', 'eccn', 'email', 'entry', 'eta', 'etd', 'event', 'exception',
    'excise', 'export', 'exportation', 'exw', 'fas', 'fax', 'fcl', 'feeder', 'fees', 'feu', 'flat', 'flight', 'fob',
    'forwarder', 'free', 'freight', 'gp', 'gross', 'gst', 'handling', 'hazardous', 'hbl', 'hc', 'height', 'high',
    'hr', 'hs', 'hs-code', 'hscode', 'hts', 'id', 'imdg', 'imo', 'import', 'importation', 'impression', 'impresion',
    'incoterms', 'inch', 'inches', 'inspection', 'insurance', 'intermodal', 'inv', 'invoice', 'invoices', 'iso',
    'item', 'items', 'iva', 'jumbo', 'kg', 'kgs', 'lading', 'largo', 'lcl', 'length', 'license', 'load', 'loaded',
    'loading', 'logistics', 'loose', 'loss', 'lot', 'lote', 'm3', 'manifest', 'marks', 'mbl', 'measurement',
    'measurements', 'medium', 'meter', 'metric', 'milestone', 'mm', 'mode', 'mt', 'multimodal', 'ncm', 'net',
    'netweight', 'no', 'non-hazardous', 'non-stackable', 'note', 'notes', 'notify', 'number', 'numbers', 'nvocc',
    'of', 'only', 'open', 'order', 'origin', 'packaging', 'packing', 'pallet', 'pallets', 'palletized', 'party',
    'payable', 'pc', 'pcs', 'permit', 'phytosanitary', 'pickup', 'piece', 'pieces', 'pkg', 'pkgs', 'pl', 'plt',
    'plts', 'po', 'port', 'prepaid', 'qty', 'quantity', 'quota', 'rack', 'rail', 'reefer', 'reel', 'reels', 'ref',
    'reference', 'report', 'restriction', 'rfc', 'roll', 'rolls', 'routing', 'sack', 'sacks', 'said', 'sailing',
    'scac', 'schedule', 'seal', 'seals', 'serial', 'sheets', 'shipment', 'shipper', 'shipping', 'sin', 'size',
    'sizes', 'small', 'stackable', 'status', 'stc', 'storage', 'stowed', 'stuffing', 'surcharges', 'survey',
    'system', 'tank', 'tare', 'tariff', 'tax', 'temperature', 'temp', 'terminal', 'teu', 'time', 'to', 'ton',
    'tons', 'top', 'total', 'tracking', 'tracing', 'trade', 'transit', 'transload', 'transhipment', 'transport',
    'truck', 'un', 'unit', 'unstuffing', 'valuation', 'value', 'vat', 'vessel', 'volume', 'voyage', 'warehouse',
    'weight', 'width', 'x', 'zone'
}


stop_words = spanish_stopwords.union(additional_stopwords)
stop_words = stop_words.union(english_stopwords)

# Function to preprocess text
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text.strip()

# Function to translate text to English
def translate_to_english(text, tokenizer, model):
    translated = model.generate(**tokenizer.prepare_seq2seq_batch([text], return_tensors="pt"))
    return tokenizer.decode(translated[0], skip_special_tokens=True)

# Function to lemmatize, remove nonsense words, and clean text
def lemmatize_and_clean(text):
    words = text.split()
    cleaned_words = []
    for word in words:
        lemma = lemmatizer.lemmatize(word)
        if lemma in english_words and lemma not in stop_words:
            cleaned_words.append(lemma)
    return cleaned_words  # Return list of cleaned words

# Function to get top tokens based on frequency and attention scores
def get_top_tokens(text, top_n=3):
    inputs = bert_tokenizer(text, return_tensors='pt')
    outputs = bert_model(**inputs)
    
    # Get the attention scores (mean pooling over token embeddings)
    attention_scores = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
    
    # Create a dictionary of tokens and their corresponding attention scores
    tokens_with_scores = {token_id: score for token_id, score in zip(inputs['input_ids'][0], attention_scores)}
    
    # Filter out special tokens and get full tokens without subword prefixes
    filtered_tokens_scores = {}
    
    for token_id, score in tokens_with_scores.items():
        if token_id not in [bert_tokenizer.pad_token_id, bert_tokenizer.cls_token_id, bert_tokenizer.sep_token_id]:
            token_str = bert_tokenizer.decode([token_id]).replace("##", "")
            filtered_tokens_scores[token_str] = score
    
    # Count occurrences of each token in the cleaned words list for additional scoring
    word_counts = Counter(lemmatize_and_clean(text))
    
    # Combine frequency counts with attention scores for final ranking
    combined_scores = {token: word_counts[token] + filtered_tokens_scores.get(token, 0) for token in filtered_tokens_scores}
    
    # Sort by combined score and get top N tokens
    top_tokens = sorted(combined_scores.items(), key=lambda item: item[1], reverse=True)[:top_n]
    
    return [token for token, _ in top_tokens]

# Full pipeline function
def process_text(text, type):
    try:
        # Step 1: Preprocess
        preprocessed_text = preprocess_text(text)
        
        # Step 2: Translate
        translated_text = translate_to_english(preprocessed_text, tokenizer, model)
        
        # Step 3: Lemmatize, remove nonsense words, and clean
        cleaned_words_list = lemmatize_and_clean(translated_text)
        
        # Convert cleaned words list back to string for attention scoring
        final_cleaned_text = " ".join(cleaned_words_list)

        # Step 4: Get top tokens based on frequency and attention scores
        top_tokens = get_top_tokens(final_cleaned_text)
        top_tokens = " ".join(top_tokens)

        # Return based on the type parameter
        if type == 1:
            return final_cleaned_text
        else:
            return top_tokens
        
    except Exception as e:
        print(f"An error occurred: {e}")
        return ""

    except Exception as e:
        print(f"Error processing text: {text}")
        print(f"Error message: {str(e)}")
        return "", []  # Return empty string and empty list in case of error
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\juan-\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\juan-\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\juan-\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\juan-\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Function to simulate Monte Carlo runs

two_digit_accuracies = []
four_digit_accuracies = []

def monte_carlo_simulation(validation_data, df, num_runs=10):


    for run in range(num_runs):
        # Generate 30 random indices from the validation set
        random_indices = np.random.choice(validation_data.index, size=30, replace=False)
        
        correct_two_digits = 0
        correct_four_digits = 0

        for idx in random_indices:
            validation_input = validation_data.loc[idx, 'Raw_data_input']
            expected_two_digits = validation_data.loc[idx, 'Expected_output_two_digits']
            expected_four_digits = validation_data.loc[idx, 'Expected_output_four_digits']

            # Check if validation_input is a valid string
            if isinstance(validation_input, str):
                # Run prediction function with the original df
                predicted_code = predict_hs_code(process_text(validation_input,1))

                # Log the index, expected, predicted values, and the input description
                print(f"Run {run + 1}, Index: {idx}, Input Description: '{validation_input}', "
                      f"Expected 2-Digit: {expected_two_digits}, Predicted: {predicted_code[:2]}, "
                      f"Expected 4-Digit: {expected_four_digits}, Predicted: {predicted_code}")
                
                #print(predicted_code[:2])
                #print(predicted_code[:4])
                #print(expected_two_digits)
                #print(expected_four_digits)

                # Check accuracy for 2-digit and 4-digit codes
                if str(predicted_code[:2]) == str(expected_two_digits).strip():
                    correct_two_digits += 1
                    #print(correct_two_digits)

                if str(predicted_code[:4]) == str(expected_four_digits).strip():
                    correct_four_digits += 1
                    #print(correct_four_digits)
            else:
                print(f"Warning: Invalid input for index {idx}: {validation_input}")

        # Calculate accuracies

        
        two_digit_accuracy = correct_two_digits / 30
        four_digit_accuracy = correct_four_digits / 30

        two_digit_accuracies.append(two_digit_accuracy)
        four_digit_accuracies.append(four_digit_accuracy)

    return two_digit_accuracies, four_digit_accuracies

# Assuming df is your original DataFrame with all the necessary data
# Assuming validation_data is your DataFrame specifically for validation
two_digit_accuracies, four_digit_accuracies = monte_carlo_simulation(validation_df, df)

# Plot the results
plt.figure(figsize=(12, 6))
plt.boxplot([two_digit_accuracies, four_digit_accuracies], labels=['2-Digit Accuracies', '4-Digit Accuracies'])
plt.title('Monte Carlo Simulation: HS Code Prediction Accuracies')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.grid(axis='y')
plt.show()

print(two_digit_accuracies)
print(four_digit_accuracies)
# Out:
# Run 1, Index: 76, Input Description: 'LUPOLEN GX 5038 14 PAL770 BAGSLOADED ONTO14 PALLETS LOADED INTO1 40  HIGH CUBE CONTAINERLUPOLEN GX 5038IN 25 KG BAGHS CODE   39012090NET WEIGHT  19250 0000 KGSHS NO 3901209039012090  HS  FREIGHT PREPAIDSHIPPED ON BOARDPO 5500062180OCEAN FCLDOOR TO PO', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3901, Predicted: 841013
# Run 1, Index: 12, Input Description: 'PLASTIC ARTICLES HS CODE 392490', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3924, Predicted: 490800
# Run 1, Index: 22, Input Description: 'PLASTIC PROFILES  HS CODE 3916 1000 3916 90507326 2000   NCM CODES 3916 9050 7326 2000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3916, Predicted: 841000
# Run 1, Index: 28, Input Description: 'ALUMINIUM BILLET ALLOY 606 3IN - 9 HS CODE 7601 20 COUNTRY OF ORIGIN INDIA TOTAL GROSS WT MT 103.4 25 TOTAL NET WT MT 103. 025 TOTAL BUNDLES 40 TOT AL PIECES 160 SHIPPING BILL NO 4000013 SHIPPING BILL DATE 04.01.2021 14 CALENDAR DA', Expected 2-Digit: 76, Predicted: 75, Expected 4-Digit: 7601, Predicted: 750522
# Run 1, Index: 197, Input Description: 'JOINING STATION WITH UKS X296 INJECTION MOULDING TOOL X296 HS CODE 84779010 84807100', Expected 2-Digit: 84, Predicted: 96, Expected 4-Digit: 8477, Predicted: 960810
# Run 1, Index: 92, Input Description: 'WASTE PAPER SORTED WHITE LEDGER HS CODE 4707200000', Expected 2-Digit: 47, Predicted: 47, Expected 4-Digit: 4707, Predicted: 470700
# Run 1, Index: 171, Input Description: '7 PACKAGES COLD ROLLED STE EL HS CODE 7211.23.30.00.1 9 NET WEIGHT 19976 KGS', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7211, Predicted: 721410
# Run 1, Index: 146, Input Description: 'GALVANIZED STEEL STRAND HS CODE 7312.10.65', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7312, Predicted: 721700
# Run 1, Index: 190, Input Description: 'PAPER TOTAL 175 REELS PERFORMANCE WHITE SE WHITE SACK PAPER HS CODE 48042910 ORDER REF 743265 CIF VERACRUZ INCOTERMS 2020', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4804, Predicted: 370300
# Run 1, Index: 24, Input Description: '7X40DC. 5X40HC. SAID TO CONTAIN 264 SKIDS THERMOFORMED TRAYS HS CODE 39239000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3923, Predicted: 842699
# Run 1, Index: 196, Input Description: 'MIXTURE OF ODORIFEROUS SUBSTANCES HS CODE 330210 FREIGHT PREPAID SHIPPER S STOW LOAD COUNT', Expected 2-Digit: 33, Predicted: 28, Expected 4-Digit: 3302, Predicted: 281512
# Run 1, Index: 193, Input Description: '900 BAGS MOLDING PE06 HS CODE 39012090', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3901, Predicted: 841122
# Run 1, Index: 103, Input Description: 'Q.D.C. 8 REEL 1X40 GP CONTAINER S.T.C.: PAPERBOARD MATERIAL CODE: R1627-618 HS CODE 48109230', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 1, Index: 16, Input Description: 'SODIUM BISULFATE 20X1200 K G BIGBAGS ON 20 PLALETS NE T 24.000 KG HS CODE 28331 9', Expected 2-Digit: 28, Predicted: 28, Expected 4-Digit: 2833, Predicted: 283330
# Run 1, Index: 93, Input Description: 'CAR PARTS HS CODE 87082910', Expected 2-Digit: 87, Predicted: 62, Expected 4-Digit: 8708, Predicted: 620400
# Run 1, Index: 7, Input Description: 'SODIUM BISULFATE 960X25 KG PE BAGS ON 20 PALLETS NET 24.000 KG HS CODE 283319', Expected 2-Digit: 28, Predicted: 28, Expected 4-Digit: 2833, Predicted: 283210
# Run 1, Index: 39, Input Description: '900 SACK FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 1, Index: 218, Input Description: '1X20DC. SAID TO CONTAIN 20 PAL TANNING EXTRACTS DYEING EXTRACTS PAINTS VARNISHES S.O. REACTIVE DYES 20 PALLETS 480 PACKAGES WITH 20 PALLETS REACTIVE YELLOW 145 AMARILLO 145 HS CODE 32041610  REACTIVE BLUE 171 115 AZUL 171 HS CODE 32041650  REACTIVE B', Expected 2-Digit: 32, Predicted: 11, Expected 4-Digit: 3204, Predicted: 110812
# Run 1, Index: 134, Input Description: '1X40HC. SAID TO CONTAIN 25 SKID PLASTIC PLASTIC ARTICLES NEW 600 CARTONS PLASTIC CAPS HS CODE 39235090 FREIGHT PREPAID  FREIGHT PREPAID', Expected 2-Digit: 39, Predicted: 69, Expected 4-Digit: 3923, Predicted: 691010
# Run 1, Index: 188, Input Description: 'ON 33 PALLETS OF NON HAZARDOUS PHARMACEUTICAL PRODUCTS HS CODE 30049000 CAAT IS DONE BY OURSELVES SCACCODE TSVC16500-384760 TRANSPORTATION UNDER CONTROLLED TEMPERATURE AT 20 C REF BLXMSC012020 FREIGHT PAYABLE AT LE HAVRE', Expected 2-Digit: 30, Predicted: 85, Expected 4-Digit: 3004, Predicted: 854890
# Run 1, Index: 21, Input Description: '36 PACKAGES AUTOMOTIVE SPARE HS CODE 87089997', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850433
# Run 1, Index: 129, Input Description: 'Q.D.C. 9 REEL 1X40 GP CONTAINER S.T.C.: PAPERBOARD MATERIAL CODE: R1656-545 HS CODE 48109230 CONTAINER(S) LOADED AT: STORA ENSO OYJ PACKAGING IMATRA MILLS IMATRA 55800 FINLAND', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 1, Index: 167, Input Description: 'MUEBLES Y ESTANTERIAS HS CODE 940310', Expected 2-Digit: 94, Predicted: 62, Expected 4-Digit: 9403, Predicted: 620920
# Run 1, Index: 29, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00058 OUR SCAC CODE POLN', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 1, Index: 91, Input Description: '5X40HR SAID TO CONTAIN 242 ROLLS APET PLASTICS SHEET IN ROLL FORM HS CODE392062 TAX ID PLA130417ED5 TEL52 55 5822 8000 E MAILANB WOW.COM.MX PLATES SHEETS FILM FOIL PLASTIC', Expected 2-Digit: 39, Predicted: 44, Expected 4-Digit: 3920, Predicted: 441300
# Run 1, Index: 26, Input Description: 'PVC ROLLSHS CODE 39204910', Expected 2-Digit: 39, Predicted: 01, Expected 4-Digit: 3920, Predicted: 010000
# Run 1, Index: 175, Input Description: '1 UNIT FLOUR MILL CONVEYIN G MACHINERY AND EQUIPMENT AT THE DISMANTLED STATE PNEUMATIC CONVEYING GRAIN IMPURITIES SYSTEM WITH AC CESSORIES TO NORMAL OPERA TION HS CODE 8437.80', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8437, Predicted: 843610
# Run 1, Index: 159, Input Description: '1X40DC. SAID TO CONTAIN 9 REELS PLASTIC PLASTIC ARTICLES NEW PAPERBOARD MATERIAL CODE R1627 627 HS CODE 48109230 FREIGHT PREPAID', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 1, Index: 68, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406 FREIGHT PREPAIDSHIPPED ON BOARD T 52 55 47507100', Expected 2-Digit: 94, Predicted: 10, Expected 4-Digit: 9406, Predicted: 100200
# Run 1, Index: 136, Input Description: 'STC 20000KG X VALOSIN 425 1000 BAGS X 20KG EACH HS CODE 30042099 ANIMAL HEALTH PHARMACEUTICALSNONHAZ', Expected 2-Digit: 30, Predicted: 51, Expected 4-Digit: 3004, Predicted: 510000
# Run 2, Index: 162, Input Description: 'PHARMA CANESTEN 2 20G MX HS CODE 30049000000 0123578985000010 LOADED ON 46 PAL', Expected 2-Digit: 30, Predicted: 84, Expected 4-Digit: 3004, Predicted: 841122
# Run 2, Index: 80, Input Description: 'ALUMINIUMSTRIP HS CODE 760612', Expected 2-Digit: 76, Predicted: 84, Expected 4-Digit: 7606, Predicted: 841122
# Run 2, Index: 96, Input Description: '822 PACKAGES 180 PACKAGES - KGS 1584.00 WINE - HS CODE 220410 40 PACKAGES - KGS 318.00 WINE - HS CODE 220421 540 PACKAGES- KGS 5400.00 WINE - HS CODE 220410 17 PACKAGES - KGS 273.20 WINE AND OIL - HS CODE 220421 - 150910 12 PACKAGES - KGS 93.60 WINE', Expected 2-Digit: 22, Predicted: 23, Expected 4-Digit: 2204, Predicted: 230700
# Run 2, Index: 216, Input Description: 'STEEL BARS HS CODE 72283061  NCM CODES 72283061', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7228, Predicted: 721700
# Run 2, Index: 150, Input Description: 'YAGMAKSAN H.V. SWITCH PAR TS HS CODE 85389099 1 PAC KAGES 555 KG FKK GUNEY JOU NCE BUMPER 001451000874 PO 55009005 HS CODE 40169952 72 PACKAGE ON 6 PALLET HS CODE S 401699 1188 KG TE RMAL MICROSWITCH SWITCH HARNESS HS CODE 85365 080 5 PAL', Expected 2-Digit: 85, Predicted: 28, Expected 4-Digit: 8538, Predicted: 284030
# Run 2, Index: 46, Input Description: '37 PACKAGES AUTOMOTIVE SPARE HS CODE 87089997', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850433
# Run 2, Index: 106, Input Description: '5X40HR SAID TO CONTAIN 212 ROLLS PLATES SHEETS FILM FOIL PLASTIC APET PLASTICS SHEET IN ROLL FORM HS CODE392062 TAX ID PLA130417ED5 FREIGHT PREPAID TEL52 55 5822 8000 E MAILANB WOW.COM.MX', Expected 2-Digit: 39, Predicted: 44, Expected 4-Digit: 3920, Predicted: 441300
# Run 2, Index: 97, Input Description: 'CS STEEL SHOT HS CODE72052900 . . . . .', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7205, Predicted: 720700
# Run 2, Index: 23, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 1737 PCS; 281232 8222 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 2, Index: 188, Input Description: 'ON 33 PALLETS OF NON HAZARDOUS PHARMACEUTICAL PRODUCTS HS CODE 30049000 CAAT IS DONE BY OURSELVES SCACCODE TSVC16500-384760 TRANSPORTATION UNDER CONTROLLED TEMPERATURE AT 20 C REF BLXMSC012020 FREIGHT PAYABLE AT LE HAVRE', Expected 2-Digit: 30, Predicted: 85, Expected 4-Digit: 3004, Predicted: 854890
# Run 2, Index: 183, Input Description: '12 PACKAGES OF SPARE PARTS FOR MACHINERY INVOICE NO ITPA049210323 HS CODE 8431499000 NCM CODES 84314', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8431, Predicted: 843420
# Run 2, Index: 99, Input Description: 'FREE-CUTTING STEEL SPECIFICATION C12L14 C HS CODE 72151000', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 720700
# Run 2, Index: 3, Input Description: 'PAPER FOR CORES K 05 HS CODE48239085 NCM CODES 48239085   ZZ 480100', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4823, Predicted: 370300
# Run 2, Index: 128, Input Description: 'FORKLIFT TRUCKS HS CODE 842720 PO 4500197904', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8427, Predicted: 841122
# Run 2, Index: 110, Input Description: 'ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS', Expected 2-Digit: 39, Predicted: 01, Expected 4-Digit: 3923, Predicted: 010000
# Run 2, Index: 22, Input Description: 'PLASTIC PROFILES  HS CODE 3916 1000 3916 90507326 2000   NCM CODES 3916 9050 7326 2000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3916, Predicted: 841000
# Run 2, Index: 104, Input Description: 'FREE-CUTTING STEELS COLD DRAWN HS CODE 72151000', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 722820
# Run 2, Index: 175, Input Description: '1 UNIT FLOUR MILL CONVEYIN G MACHINERY AND EQUIPMENT AT THE DISMANTLED STATE PNEUMATIC CONVEYING GRAIN IMPURITIES SYSTEM WITH AC CESSORIES TO NORMAL OPERA TION HS CODE 8437.80', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8437, Predicted: 843610
# Run 2, Index: 140, Input Description: 'PAPER FOR CORES K05 HS CODE48239085 NCM CODES 48239085   ZZ 482390', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4823, Predicted: 370300
# Run 2, Index: 122, Input Description: 'CONTAINER PLYWOOD PARTS HS CODE4412991090 PHONE 86 755 82688282 FAX 86 7 55 33975763 TAX ID914403005', Expected 2-Digit: 44, Predicted: 44, Expected 4-Digit: 4412, Predicted: 441840
# Run 2, Index: 109, Input Description: 'AUTOMOTIVE SPARE HS CODE 87085099', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 283200
# Run 2, Index: 71, Input Description: 'TOTAL 2580 BOXES PACKED IN 81 PALLETS GLAZED VITRIFI ED FLOOR TILES COLOURED IN VOICE NO 05021-22 DT 07.05.2021 SHIPPING BILL NO 1648470 DT 08.05.202 1 HS CODE 69072100 TOTAL GROSS WT 81786.00 KGS TO TAL NET WT 81270.00 KGS FREIGHT', Expected 2-Digit: 69, Predicted: 56, Expected 4-Digit: 6907, Predicted: 560210
# Run 2, Index: 142, Input Description: 'LAMINATE FLOORING HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 2, Index: 100, Input Description: '1071 CARTONS PLASTIC KITCH ENWARE AND BATHROOM ITEMS HS CODE 392410  392630  392490 NET WEIGHT 2636 KGS', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3924, Predicted: 490800
# Run 2, Index: 125, Input Description: '1X40DC. SAID TO CONTAIN 13 CARTONS 13 CTNS CONTAINING 296 PCS OF WOMENS SHIRT HS CODE6206303011 PO 2100000186 STYLE 57784 0002 PO NO.2100000186     STYLE NO.57784 0002 13 CTNS CONTAINING 296 PCS OF WOMENS SHIRT HS CODE6206303011 PO 2100000186 STYLE 5', Expected 2-Digit: 62, Predicted: 28, Expected 4-Digit: 6206, Predicted: 282800
# Run 2, Index: 138, Input Description: 'NEW AUTOMOTIVE PARTS HS CODE 87089499', Expected 2-Digit: 87, Predicted: 69, Expected 4-Digit: 8708, Predicted: 691010
# Run 2, Index: 201, Input Description: 'STEEL BARS HS CODE 72283061', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7228, Predicted: 721700
# Run 2, Index: 20, Input Description: 'AUTOMOTIVE SPARE PARTS HS CODE 87089390; 73159000; 45054089; 45054082;', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 284030
# Run 2, Index: 39, Input Description: '900 SACK FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 2, Index: 149, Input Description: 'SODIUM LIGNOSULPHONATE LIGNOSULPHONATE DOMSJOE LIGNIN DS 10 TOTAL 400 BIG BAGS NET WEIGHT 240000 KGS GROSS WEIGHT 244000 KGS HS CODE 38040000', Expected 2-Digit: 38, Predicted: 28, Expected 4-Digit: 3804, Predicted: 283210
# Run 3, Index: 106, Input Description: '5X40HR SAID TO CONTAIN 212 ROLLS PLATES SHEETS FILM FOIL PLASTIC APET PLASTICS SHEET IN ROLL FORM HS CODE392062 TAX ID PLA130417ED5 FREIGHT PREPAID TEL52 55 5822 8000 E MAILANB WOW.COM.MX', Expected 2-Digit: 39, Predicted: 44, Expected 4-Digit: 3920, Predicted: 441300
# Run 3, Index: 14, Input Description: 'PHARMA ASPIRINA PROTECT 100MG 84ST HS CODE 30049000000 0123659272000010 LOADED ON 5 PAL PO 2270046622 DELIVERY NO. 123659272 INVOICE NO. 813A108353 NAMED ACCOUNT BAYER', Expected 2-Digit: 30, Predicted: 91, Expected 4-Digit: 3004, Predicted: 910400
# Run 3, Index: 54, Input Description: '1X20DC. SAID TO CONTAIN 21 PKGS 72222039 HS BRIGHT BARS HOT ROLLED STAINLESS FERRITE 1.4104 CORRODUR 4104 X 14 CRMOS 17 HOT ROLLED PEELED TOL. ISO H9 OF CONTINUOUS CAST HS CODE 72222039  FREIGHT PREPAID 72222039 HS BRIGHT BARS HOT ROLLED STAINLESS FE', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7222, Predicted: 721650
# Run 3, Index: 2, Input Description: 'FREE-CUTTING STEELS COLD DRAWN SPECIFICATION C12L14C HS CODE 72151000', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 722820
# Run 3, Index: 29, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00058 OUR SCAC CODE POLN', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 3, Index: 151, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 314 PCS; 2809128 163 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 3, Index: 111, Input Description: 'HACOFLEX 3405 HS CODE 39199080', Expected 2-Digit: 39, Predicted: 10, Expected 4-Digit: 3919, Predicted: 100400
# Run 3, Index: 31, Input Description: 'LAMINATE FLOORING ITEM 13298512  ORDER 3072 HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 3, Index: 38, Input Description: 'FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 3, Index: 101, Input Description: 'AUTOMOTIVE SPARE PARTS INVOICE 20-017 HS CODE 870810', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 284030
# Run 3, Index: 113, Input Description: 'AUTOMOTIVE PARTS HS CODE 87089299 EXW EDENKOBEN', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 3, Index: 12, Input Description: 'PLASTIC ARTICLES HS CODE 392490', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3924, Predicted: 490800
# Run 3, Index: 214, Input Description: 'PAPER  HS CODE 4810 1300 ORDER 2218076NCM CODES 4810 1300', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4810, Predicted: 370300
# Run 3, Index: 173, Input Description: 'BRUFASOL YELLOW AL 30 HS CODE 32064970', Expected 2-Digit: 32, Predicted: 28, Expected 4-Digit: 3206, Predicted: 283330
# Run 3, Index: 117, Input Description: 'CERAMIC TABLEWARE 2688 BO XES HS CODE 69120029', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6912, Predicted: 270120
# Run 3, Index: 139, Input Description: 'SPIRITS HS CODE 2208  NCM CODES 220870', Expected 2-Digit: 22, Predicted: 28, Expected 4-Digit: 2208, Predicted: 283630
# Run 3, Index: 89, Input Description: '2965 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 3, Index: 30, Input Description: '48 AUTOMOTIVE PARTS HS CODE 87081090', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 3, Index: 57, Input Description: 'SODIUM LIGNOSULPHONATE DOMSJOE LIGNIN DS 10 TOTAL 80 BIG BAGS NET WEIGHT 48000 KGS GROSS WEIGHT 48800 KGS HS CODE 38040000', Expected 2-Digit: 38, Predicted: 84, Expected 4-Digit: 3804, Predicted: 841100
# Run 3, Index: 53, Input Description: 'OFFICE CHAIRS AND PARTS  HS CODE 9401 9080 7320 20817318 1568 7318 1290 6006 3200 6005 3700 5903 209', Expected 2-Digit: 94, Predicted: 69, Expected 4-Digit: 9401, Predicted: 691000
# Run 3, Index: 23, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 1737 PCS; 281232 8222 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 3, Index: 80, Input Description: 'ALUMINIUMSTRIP HS CODE 760612', Expected 2-Digit: 76, Predicted: 84, Expected 4-Digit: 7606, Predicted: 841122
# Run 3, Index: 44, Input Description: '1X20DC. SAID TO CONTAIN 21 PKGS IRON STEEL IRON AND STEEL ARTICLES METAL 72285020 HS BRIGHT BARS HOT ROLLED STAINLESS FERRITE 1.4104 CORRODUR 4104 X 14 CRMOS 17 HOT ROLLED PEELED TOL. ISO H9 OF CONTINUOUS CAST HS CODE 72222039', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7222, Predicted: 721300
# Run 3, Index: 75, Input Description: 'TECHNICAL FURNITURE HS CODE 9403', Expected 2-Digit: 94, Predicted: 62, Expected 4-Digit: 9403, Predicted: 620920
# Run 3, Index: 76, Input Description: 'LUPOLEN GX 5038 14 PAL770 BAGSLOADED ONTO14 PALLETS LOADED INTO1 40  HIGH CUBE CONTAINERLUPOLEN GX 5038IN 25 KG BAGHS CODE   39012090NET WEIGHT  19250 0000 KGSHS NO 3901209039012090  HS  FREIGHT PREPAIDSHIPPED ON BOARDPO 5500062180OCEAN FCLDOOR TO PO', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3901, Predicted: 841013
# Run 3, Index: 149, Input Description: 'SODIUM LIGNOSULPHONATE LIGNOSULPHONATE DOMSJOE LIGNIN DS 10 TOTAL 400 BIG BAGS NET WEIGHT 240000 KGS GROSS WEIGHT 244000 KGS HS CODE 38040000', Expected 2-Digit: 38, Predicted: 28, Expected 4-Digit: 3804, Predicted: 283210
# Run 3, Index: 112, Input Description: 'CONTAINED IN 50 PALLEST OF COSMETIC PRODUCTS HS CODE 330590', Expected 2-Digit: 33, Predicted: 39, Expected 4-Digit: 3305, Predicted: 392690
# Run 3, Index: 215, Input Description: 'SHOWCAR 1999 FERRARI F399 - VIN26 HS CODE8703.23', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8703, Predicted: 841122
# Run 3, Index: 118, Input Description: '48 PKGS AUTOMOTIVE PARTS HS CODE 87088099', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 3, Index: 110, Input Description: 'ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS', Expected 2-Digit: 39, Predicted: 01, Expected 4-Digit: 3923, Predicted: 010000
# Run 4, Index: 24, Input Description: '7X40DC. 5X40HC. SAID TO CONTAIN 264 SKIDS THERMOFORMED TRAYS HS CODE 39239000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3923, Predicted: 842699
# Run 4, Index: 168, Input Description: 'FREIGHT PREPAIDUNASSEMBLED PART FOR PANSHS CODE 39269097 73239400SPARE PARTS HS CODE84311000 8481209039269097  HS', Expected 2-Digit: 39, Predicted: 90, Expected 4-Digit: 3926, Predicted: 902910
# Run 4, Index: 152, Input Description: 'CONTAINING 231 CARTONS  SOAP BASE HS CODE 3402190 FREIGHT PREPAID NCM CODES 3402190', Expected 2-Digit: 34, Predicted: 83, Expected 4-Digit: 3402, Predicted: 830621
# Run 4, Index: 140, Input Description: 'PAPER FOR CORES K05 HS CODE48239085 NCM CODES 48239085   ZZ 482390', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4823, Predicted: 370300
# Run 4, Index: 13, Input Description: 'ALUMINUM SLUG  DOMED INOTALVIBRATIONALLY TUMBLEDALUMINIUM ALLTUBAS PER INVOICE MEXICOSK 21 1335 000465AS PER CUSTOMS INVOICE VAM 21100059HS CODE  760691ALUMINUM SLUG  DOMED VIBRATIONALLY TUMBLEDAS PER INVOICE SK 21 1335 000469AS PER CUSTOMS INVOICE V', Expected 2-Digit: 76, Predicted: 85, Expected 4-Digit: 7606, Predicted: 850432
# Run 4, Index: 79, Input Description: 'VOLVO RELATED BUS PARTS IN CKD CONDITION HS CODE 87060011  FREIGHT PREPAID NCM CODES 870600', Expected 2-Digit: 87, Predicted: 90, Expected 4-Digit: 8706, Predicted: 902910
# Run 4, Index: 105, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 485 PCS; 2815228 242 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 4, Index: 185, Input Description: 'CONSOLIDATED AUTOMOTIVE PARTSHS CODE 870899FREIGHT PREPAIDGENERAL CMA CGM TERMS AND CONDITIONS TO BE FOUNDUNDER WWW CMA CGM COMTHIS MASTERBILL COVERS AUTOMATED NVOCC HOUSEBILL', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850431
# Run 4, Index: 48, Input Description: 'SUBMERSIBLE PUMP HS CODE 84139100', Expected 2-Digit: 84, Predicted: 28, Expected 4-Digit: 8413, Predicted: 283330
# Run 4, Index: 108, Input Description: 'PAPER TOTAL 21 REELS ORDER REF 741546 RELEASE 85 BLEACHED MG KRAFT PAPER HS CODE 48043980 CIF VERACRUZ INCOTERMS 2020', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4804, Predicted: 370300
# Run 4, Index: 118, Input Description: '48 PKGS AUTOMOTIVE PARTS HS CODE 87088099', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 4, Index: 55, Input Description: 'AUTOMOTIVE PARTSAUTOMOTIVE PARTSINVOICE NUMBERFILE  500 2459007948852620 147 115 109 CMSHS CODE   870899AUTOMOTIVE PARTSINVOICE NUMBERFILE  500 2459007948852720 147 115 109 CMSHS CODE   870899AUTOMOTIVE PARTSINVOICE NUMBERFILE  500 2459007948852820 1', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850450
# Run 4, Index: 174, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406 902480', Expected 2-Digit: 94, Predicted: 54, Expected 4-Digit: 9406, Predicted: 540720
# Run 4, Index: 106, Input Description: '5X40HR SAID TO CONTAIN 212 ROLLS PLATES SHEETS FILM FOIL PLASTIC APET PLASTICS SHEET IN ROLL FORM HS CODE392062 TAX ID PLA130417ED5 FREIGHT PREPAID TEL52 55 5822 8000 E MAILANB WOW.COM.MX', Expected 2-Digit: 39, Predicted: 44, Expected 4-Digit: 3920, Predicted: 441300
# Run 4, Index: 62, Input Description: 'PAPER  HS CODE 4810 1300 ORDER 2218198NCM CODES 4810 1300', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4810, Predicted: 370300
# Run 4, Index: 80, Input Description: 'ALUMINIUMSTRIP HS CODE 760612', Expected 2-Digit: 76, Predicted: 84, Expected 4-Digit: 7606, Predicted: 841122
# Run 4, Index: 187, Input Description: 'COLD ROLLED STAINLESS STEEL COILS 1 4301   304PL 42149004 42149005 42149015 42149016HS CODE  72202081 72202041 72193510ORDER NO  S O 1000385746  1000386810  1000392536 1000392537GROSS NET WEIGHT  17668 16802 KGS  CONTACT PHONE   52 442 659 5459FREIGH', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7220, Predicted: 721300
# Run 4, Index: 77, Input Description: 'INDUSTRIAL MATERIAL HS CODE 72151000FREIGHT PAYABLE AT LE HAVRE', Expected 2-Digit: 72, Predicted: 97, Expected 4-Digit: 7215, Predicted: 970300
# Run 4, Index: 181, Input Description: 'RING-GEAR PREF(INSTALLATION IN CARS) M0031939-40 M0032414-40 HS CODE 87085099', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 848210
# Run 4, Index: 141, Input Description: 'FREIGHT PREPAIDAUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810AUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810', Expected 2-Digit: 87, Predicted: 58, Expected 4-Digit: 8708, Predicted: 581000
# Run 4, Index: 19, Input Description: 'PAPER  HS CODE 4810 1300 ORDER 2218 1991NCM CODES 4810 1300', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4810, Predicted: 370300
# Run 4, Index: 104, Input Description: 'FREE-CUTTING STEELS COLD DRAWN HS CODE 72151000', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 722820
# Run 4, Index: 172, Input Description: 'PARTS SUITABLE FOR USE SOL ELY OR PRINCIPALLY WITH TH E ENGINES OF HEADING 8407 OR 8408 CYLINDER LINERS HS CODE 84099941 TOTAL NO O F CYLINDERS 20794 TOTAL N O OF PALLETS 44 INVOICE N O 14004239 DATE 28.05.2 021 SHIPPING BILL NO 4001 272 DATE', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8409, Predicted: 840734
# Run 4, Index: 117, Input Description: 'CERAMIC TABLEWARE 2688 BO XES HS CODE 69120029', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6912, Predicted: 270120
# Run 4, Index: 210, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00060', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 4, Index: 218, Input Description: '1X20DC. SAID TO CONTAIN 20 PAL TANNING EXTRACTS DYEING EXTRACTS PAINTS VARNISHES S.O. REACTIVE DYES 20 PALLETS 480 PACKAGES WITH 20 PALLETS REACTIVE YELLOW 145 AMARILLO 145 HS CODE 32041610  REACTIVE BLUE 171 115 AZUL 171 HS CODE 32041650  REACTIVE B', Expected 2-Digit: 32, Predicted: 11, Expected 4-Digit: 3204, Predicted: 110812
# Run 4, Index: 151, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 314 PCS; 2809128 163 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 4, Index: 125, Input Description: '1X40DC. SAID TO CONTAIN 13 CARTONS 13 CTNS CONTAINING 296 PCS OF WOMENS SHIRT HS CODE6206303011 PO 2100000186 STYLE 57784 0002 PO NO.2100000186     STYLE NO.57784 0002 13 CTNS CONTAINING 296 PCS OF WOMENS SHIRT HS CODE6206303011 PO 2100000186 STYLE 5', Expected 2-Digit: 62, Predicted: 28, Expected 4-Digit: 6206, Predicted: 282800
# Run 4, Index: 67, Input Description: 'X 40  HC. CONT: TCNU2311440 440 CTN   3348.000 KGS 0.000 M3 SEAL:149148// 40 HC   OF PLASTIC LIDS  ON 22 PALLETS  HS CODE 392350  SHIPPER S LOAD STOWAGE & COUNT  CONT TARE WEIGHT:3700  1 CONT TOT. TARE:4400.00 CARGO W:3348.000 0.000', Expected 2-Digit: 39, Predicted: 28, Expected 4-Digit: 3923, Predicted: 283200
# Run 4, Index: 2, Input Description: 'FREE-CUTTING STEELS COLD DRAWN SPECIFICATION C12L14C HS CODE 72151000', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 722820
# Run 5, Index: 70, Input Description: 'CERAMIC TABLEWARE HS CODE 691200 2688 BOXES PO 5 39547', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6912, Predicted: 270120
# Run 5, Index: 159, Input Description: '1X40DC. SAID TO CONTAIN 9 REELS PLASTIC PLASTIC ARTICLES NEW PAPERBOARD MATERIAL CODE R1627 627 HS CODE 48109230 FREIGHT PREPAID', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 5, Index: 8, Input Description: 'STEERING COMPONENTS FOR AUTOMOBILES HS CODE 870894 THYSSENKRUPP DELIVERY NOTE 82679377 82679376 82679378 82679379 82679380 82679381 82679382 82679383 82679384', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 841122
# Run 5, Index: 42, Input Description: 'MIXTURE OF ODORIFEROUS SUBSTANCES HS CODE 330210', Expected 2-Digit: 33, Predicted: 28, Expected 4-Digit: 3302, Predicted: 281512
# Run 5, Index: 128, Input Description: 'FORKLIFT TRUCKS HS CODE 842720 PO 4500197904', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8427, Predicted: 841122
# Run 5, Index: 16, Input Description: 'SODIUM BISULFATE 20X1200 K G BIGBAGS ON 20 PLALETS NE T 24.000 KG HS CODE 28331 9', Expected 2-Digit: 28, Predicted: 28, Expected 4-Digit: 2833, Predicted: 283330
# Run 5, Index: 26, Input Description: 'PVC ROLLSHS CODE 39204910', Expected 2-Digit: 39, Predicted: 01, Expected 4-Digit: 3920, Predicted: 010000
# Run 5, Index: 160, Input Description: 'AUTOMOTIVE SPARE PARTS HS CODE 870840 870893', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 284030
# Run 5, Index: 31, Input Description: 'LAMINATE FLOORING ITEM 13298512  ORDER 3072 HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 5, Index: 162, Input Description: 'PHARMA CANESTEN 2 20G MX HS CODE 30049000000 0123578985000010 LOADED ON 46 PAL', Expected 2-Digit: 30, Predicted: 84, Expected 4-Digit: 3004, Predicted: 841122
# Run 5, Index: 54, Input Description: '1X20DC. SAID TO CONTAIN 21 PKGS 72222039 HS BRIGHT BARS HOT ROLLED STAINLESS FERRITE 1.4104 CORRODUR 4104 X 14 CRMOS 17 HOT ROLLED PEELED TOL. ISO H9 OF CONTINUOUS CAST HS CODE 72222039  FREIGHT PREPAID 72222039 HS BRIGHT BARS HOT ROLLED STAINLESS FE', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7222, Predicted: 721650
# Run 5, Index: 195, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406', Expected 2-Digit: 94, Predicted: 54, Expected 4-Digit: 9406, Predicted: 540720
# Run 5, Index: 48, Input Description: 'SUBMERSIBLE PUMP HS CODE 84139100', Expected 2-Digit: 84, Predicted: 28, Expected 4-Digit: 8413, Predicted: 283330
# Run 5, Index: 141, Input Description: 'FREIGHT PREPAIDAUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810AUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810', Expected 2-Digit: 87, Predicted: 58, Expected 4-Digit: 8708, Predicted: 581000
# Run 5, Index: 64, Input Description: 'IN BULK 1 ISO TANK  NONILFENOL EN GRANEL 1 ISOTANQUE. HS CODE 29071300 NET WT 20520.000 KG TARE WT 3540.000 KG', Expected 2-Digit: 29, Predicted: 84, Expected 4-Digit: 2907, Predicted: 841122
# Run 5, Index: 49, Input Description: 'FREIGHT PREPAIDMOTORBIKESGUZZI   AIRONE 250 SPORT CHASIS  M23445BMW   R27 CHASIS  381852BMW   R27CHASIS  369354MONTESA   BRIO 91 CHASIS  MB17683BSA   250  CHASIS  39826DUCATI   250 CHASIS  MD 86154HS CODE  871150', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8711, Predicted: 842700
# Run 5, Index: 38, Input Description: 'FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 5, Index: 4, Input Description: 'CIGARETTES SO 10217102461021742687 HS CODE 2402.20.90', Expected 2-Digit: 24, Predicted: 63, Expected 4-Digit: 2402, Predicted: 630200
# Run 5, Index: 56, Input Description: 'PULLEY W P L 92HITACHIPULLEY W P GEN5  V8 1 AUTOMOTIVEON 44 PALLETSSANTA ROSA  MXHS CODE  848350PLANT 1   3DELIVERY NOTE8034586680345867PULLEY W P L 92HITACHION 44 PALLETSAUTOMOTIVEHS CODE  848350SANTA ROSA  MXPLANT 3COLLECT CHARGES DELIVERY NOTEOCEA', Expected 2-Digit: 84, Predicted: 85, Expected 4-Digit: 8483, Predicted: 850239
# Run 5, Index: 62, Input Description: 'PAPER  HS CODE 4810 1300 ORDER 2218198NCM CODES 4810 1300', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4810, Predicted: 370300
# Run 5, Index: 118, Input Description: '48 PKGS AUTOMOTIVE PARTS HS CODE 87088099', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 5, Index: 164, Input Description: 'PAPERBOARD MATERIAL CODE R1626-596 HS CODE 48109230 CONTAINER S LOADED AT KORSNAS AB GRANUDDEN S-801 81 G..VLE SWEDEN', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 5, Index: 28, Input Description: 'ALUMINIUM BILLET ALLOY 606 3IN - 9 HS CODE 7601 20 COUNTRY OF ORIGIN INDIA TOTAL GROSS WT MT 103.4 25 TOTAL NET WT MT 103. 025 TOTAL BUNDLES 40 TOT AL PIECES 160 SHIPPING BILL NO 4000013 SHIPPING BILL DATE 04.01.2021 14 CALENDAR DA', Expected 2-Digit: 76, Predicted: 75, Expected 4-Digit: 7601, Predicted: 750522
# Run 5, Index: 98, Input Description: 'POLISHED SLABS SNOW WHITE TUNDRA GRAY BRUSHED SLABS BLANCO IBIZA POLISHED SLABS HS CODE 251512', Expected 2-Digit: 25, Predicted: 25, Expected 4-Digit: 2515, Predicted: 250900
# Run 5, Index: 34, Input Description: '1X20DC. SAID TO CONTAIN 26 SKID TRANSLUCENT PAPER PALLET NOS 1 26 HS CODE 48063000 NET WEIGHT 12878KGS  FREIGHT PREPAID PAPER PAPERBOARD PACKING MATERIAL', Expected 2-Digit: 48, Predicted: 47, Expected 4-Digit: 4806, Predicted: 470710
# Run 5, Index: 20, Input Description: 'AUTOMOTIVE SPARE PARTS HS CODE 87089390; 73159000; 45054089; 45054082;', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 284030
# Run 5, Index: 40, Input Description: 'GYM EQUIPMENT AS PER COMMERCIAL INVOICE N VXUSD210182HS CODE  950691FREIGHT PREPAIDGYM EQUIPMENT AS PER COMMERCIAL INVOICE N VXUSD210182HS CODE  950691', Expected 2-Digit: 95, Predicted: 84, Expected 4-Digit: 9506, Predicted: 843621
# Run 5, Index: 1, Input Description: 'TOTAL 5040 BOXES ONLY TOTA L FIVE THOUSAND FOURTY BOX ES ONLY TOTAL 5040 BOXES P ACKED ON 92 PALLETS. POLIS HED PORCELAIN TILES SOL UBLE SALT TILES SIZE 6 00X1200MM HS CODE 6907210 0 TOTAL NET WEIGHT 107 680.00 KGS FREIGHT COLLEC T ONC C', Expected 2-Digit: 69, Predicted: 28, Expected 4-Digit: 6907, Predicted: 283400
# Run 5, Index: 52, Input Description: 'ON 41 PACKAGES 40 PAL 1 CASE OF NON HAZARDOUS PHARMACEUTICAL PRODUCTS HS CODE 30049000 30042000 CAAT IS DONE BY OURSELVES SCACCODE TSVC16500-384350 TSVC16500-386335 TRANSPORTATION UNDER CONTROLLED TEMPERATURE AT 20 C REF BLXMSC012020 FREIGHT', Expected 2-Digit: 30, Predicted: 85, Expected 4-Digit: 3004, Predicted: 854890
# Run 5, Index: 142, Input Description: 'LAMINATE FLOORING HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 6, Index: 15, Input Description: '06X20 OPEN TOP CONTAINER CONTAININGSDLT1 2021 EXT 0000006 CYLINDRES3 IHS CODE 84389000FREIGHT PREPAIDBOTTON ROLLER MILL N 03TOP ROLLER MILL N 42BOTTON ROLLER MILL N 16TOP ROLLER MILL N 38BOTTON ROLLER MILL N 33BOTTON ROLLER MILL N 07', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8438, Predicted: 848250
# Run 6, Index: 218, Input Description: '1X20DC. SAID TO CONTAIN 20 PAL TANNING EXTRACTS DYEING EXTRACTS PAINTS VARNISHES S.O. REACTIVE DYES 20 PALLETS 480 PACKAGES WITH 20 PALLETS REACTIVE YELLOW 145 AMARILLO 145 HS CODE 32041610  REACTIVE BLUE 171 115 AZUL 171 HS CODE 32041650  REACTIVE B', Expected 2-Digit: 32, Predicted: 11, Expected 4-Digit: 3204, Predicted: 110812
# Run 6, Index: 96, Input Description: '822 PACKAGES 180 PACKAGES - KGS 1584.00 WINE - HS CODE 220410 40 PACKAGES - KGS 318.00 WINE - HS CODE 220421 540 PACKAGES- KGS 5400.00 WINE - HS CODE 220410 17 PACKAGES - KGS 273.20 WINE AND OIL - HS CODE 220421 - 150910 12 PACKAGES - KGS 93.60 WINE', Expected 2-Digit: 22, Predicted: 23, Expected 4-Digit: 2204, Predicted: 230700
# Run 6, Index: 78, Input Description: '2X20TANK SAID TO CONTAIN 2 ISO SOC TANK CHEMICAL PRODUCTS NOS PCVU 2630235 26500 30200 3700 NET GROSS TARE PCVU 2250019 26500 30160 3660 NET GROSS TARE IMO 3 6.1 UN 1131 CARBON DISULPHIDE HS CODE 2813 1000 REF. NO. 18181 1 18181 2 799000084 SULFURO D', Expected 2-Digit: 28, Predicted: 38, Expected 4-Digit: 2813, Predicted: 382471
# Run 6, Index: 126, Input Description: '2X20DC. SAID TO CONTAIN 30 REELS PAPER PAPERBOARD PACKING MATERIAL NOVAPRESS O MATTE HS CODE 48102200 APPLICABLE FREE TIME 21 DAYS COMBINED DETENTION DEMURRAGE AT PORT OF DISCHARGE PLACE OF DELIVERY', Expected 2-Digit: 48, Predicted: 47, Expected 4-Digit: 4810, Predicted: 470710
# Run 6, Index: 148, Input Description: '20 IBC PHENOXY ETHANOL PR ESERVATIVE GRADE HS CODE 29094910 SB NO. 1494524 DT.30042021 IEC NO. 0 397073844 INVOICE NO. 2004 521-22 DT.30042021 BATC H NO. PE042116 IBC TANK NO. 1 - 20 NET WEIGH T 22000.00 KGS GROSS WEI GHT 2312', Expected 2-Digit: 29, Predicted: 85, Expected 4-Digit: 2909, Predicted: 850432
# Run 6, Index: 151, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 314 PCS; 2809128 163 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 6, Index: 21, Input Description: '36 PACKAGES AUTOMOTIVE SPARE HS CODE 87089997', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850433
# Run 6, Index: 35, Input Description: '23 PALLETS  WITH 92 CARTONS  SUNVISOR UPPER AND LOWER SHELL FOR BMW G05 BMW G06 HS CODE 8708 9997 NC', Expected 2-Digit: 87, Predicted: 03, Expected 4-Digit: 8708, Predicted: 030626
# Run 6, Index: 74, Input Description: 'PHARMACEUTICAL PRODUCTS INVOICE 97414806 HS CODE 300490 NCM CODES 300490', Expected 2-Digit: 30, Predicted: 39, Expected 4-Digit: 3004, Predicted: 392690
# Run 6, Index: 66, Input Description: 'AUTO PARTS / CAR PARTS HS CODE 87082910', Expected 2-Digit: 87, Predicted: 62, Expected 4-Digit: 8708, Predicted: 620452
# Run 6, Index: 83, Input Description: '2987 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 6, Index: 12, Input Description: 'PLASTIC ARTICLES HS CODE 392490', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3924, Predicted: 490800
# Run 6, Index: 184, Input Description: 'OF PHARMACEUTICAL GOODS ALL PACKED ONTO 36 PALLETS TRELEGY ELLIPTA 10062.525MCG 30DMX RELVARE 10025MCG 30DMXRELVARE 10025MCG 30 HS CODE 30043200', Expected 2-Digit: 30, Predicted: 30, Expected 4-Digit: 3004, Predicted: 300610
# Run 6, Index: 95, Input Description: '600 CARTONS PLASTIC CAPS HS CODE 39235090', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3923, Predicted: 490800
# Run 6, Index: 65, Input Description: 'STEEL FIBRES HS CODE 7205.21', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7205, Predicted: 721700
# Run 6, Index: 190, Input Description: 'PAPER TOTAL 175 REELS PERFORMANCE WHITE SE WHITE SACK PAPER HS CODE 48042910 ORDER REF 743265 CIF VERACRUZ INCOTERMS 2020', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4804, Predicted: 370300
# Run 6, Index: 39, Input Description: '900 SACK FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 6, Index: 167, Input Description: 'MUEBLES Y ESTANTERIAS HS CODE 940310', Expected 2-Digit: 94, Predicted: 62, Expected 4-Digit: 9403, Predicted: 620920
# Run 6, Index: 76, Input Description: 'LUPOLEN GX 5038 14 PAL770 BAGSLOADED ONTO14 PALLETS LOADED INTO1 40  HIGH CUBE CONTAINERLUPOLEN GX 5038IN 25 KG BAGHS CODE   39012090NET WEIGHT  19250 0000 KGSHS NO 3901209039012090  HS  FREIGHT PREPAIDSHIPPED ON BOARDPO 5500062180OCEAN FCLDOOR TO PO', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3901, Predicted: 841013
# Run 6, Index: 117, Input Description: 'CERAMIC TABLEWARE 2688 BO XES HS CODE 69120029', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6912, Predicted: 270120
# Run 6, Index: 115, Input Description: 'TOTAL 240 BOXES ONLY TWO HUNDRED FOURTY BOX ONLY 100 NATURAL INSTANT SPRAY DRIED ROASTED CHICORY BLE ND INVOICE NO.BIOIN0212 0-21 DT.09.03.2021 SB NO. 9225259 DT.09.03.2021 GROS S WT 6480.00 KGS NET WT 60 00.00 KGS HS CODE 2101309 0 GSTIN NO', Expected 2-Digit: 21, Predicted: 07, Expected 4-Digit: 2101, Predicted: 071440
# Run 6, Index: 208, Input Description: 'CONNECTORS HS CODE 853890 15630532046', Expected 2-Digit: 85, Predicted: 84, Expected 4-Digit: 8538, Predicted: 841122
# Run 6, Index: 84, Input Description: '1X20DC. SAID TO CONTAIN 6 SKID OTHER PARTS AND ACCESSORIES OF BODIES INCLUDING CABS VW416 ASSEMBLY EMBLEM REAR. PART NO. 3CM853630DPJ HS CODE87082900 CUSTOME PO NO DATE5500503193 002 05 08 2020 INV. NO.EX 220078 DT.28.05.2021 S.B. NO. 2317954 DT. 10.', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930310
# Run 6, Index: 43, Input Description: 'HYGIENE PRODUCTS HS CODE 39259010', Expected 2-Digit: 39, Predicted: 22, Expected 4-Digit: 3925, Predicted: 220410
# Run 6, Index: 171, Input Description: '7 PACKAGES COLD ROLLED STE EL HS CODE 7211.23.30.00.1 9 NET WEIGHT 19976 KGS', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7211, Predicted: 721410
# Run 6, Index: 1, Input Description: 'TOTAL 5040 BOXES ONLY TOTA L FIVE THOUSAND FOURTY BOX ES ONLY TOTAL 5040 BOXES P ACKED ON 92 PALLETS. POLIS HED PORCELAIN TILES SOL UBLE SALT TILES SIZE 6 00X1200MM HS CODE 6907210 0 TOTAL NET WEIGHT 107 680.00 KGS FREIGHT COLLEC T ONC C', Expected 2-Digit: 69, Predicted: 28, Expected 4-Digit: 6907, Predicted: 283400
# Run 6, Index: 197, Input Description: 'JOINING STATION WITH UKS X296 INJECTION MOULDING TOOL X296 HS CODE 84779010 84807100', Expected 2-Digit: 84, Predicted: 96, Expected 4-Digit: 8477, Predicted: 960810
# Run 6, Index: 97, Input Description: 'CS STEEL SHOT HS CODE72052900 . . . . .', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7205, Predicted: 720700
# Run 6, Index: 210, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00060', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 7, Index: 21, Input Description: '36 PACKAGES AUTOMOTIVE SPARE HS CODE 87089997', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850433
# Run 7, Index: 176, Input Description: '28 JUMBO ROLLS IN 28 CARDBOARD BOXES PVC COATED POLYESTER FABRIC HS CODE 39219060 FREIGHT PAYABLE AT LE HAVRE', Expected 2-Digit: 39, Predicted: 56, Expected 4-Digit: 3921, Predicted: 560210
# Run 7, Index: 71, Input Description: 'TOTAL 2580 BOXES PACKED IN 81 PALLETS GLAZED VITRIFI ED FLOOR TILES COLOURED IN VOICE NO 05021-22 DT 07.05.2021 SHIPPING BILL NO 1648470 DT 08.05.202 1 HS CODE 69072100 TOTAL GROSS WT 81786.00 KGS TO TAL NET WT 81270.00 KGS FREIGHT', Expected 2-Digit: 69, Predicted: 56, Expected 4-Digit: 6907, Predicted: 560210
# Run 7, Index: 113, Input Description: 'AUTOMOTIVE PARTS HS CODE 87089299 EXW EDENKOBEN', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 7, Index: 29, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00058 OUR SCAC CODE POLN', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 7, Index: 24, Input Description: '7X40DC. 5X40HC. SAID TO CONTAIN 264 SKIDS THERMOFORMED TRAYS HS CODE 39239000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3923, Predicted: 842699
# Run 7, Index: 80, Input Description: 'ALUMINIUMSTRIP HS CODE 760612', Expected 2-Digit: 76, Predicted: 84, Expected 4-Digit: 7606, Predicted: 841122
# Run 7, Index: 108, Input Description: 'PAPER TOTAL 21 REELS ORDER REF 741546 RELEASE 85 BLEACHED MG KRAFT PAPER HS CODE 48043980 CIF VERACRUZ INCOTERMS 2020', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4804, Predicted: 370300
# Run 7, Index: 162, Input Description: 'PHARMA CANESTEN 2 20G MX HS CODE 30049000000 0123578985000010 LOADED ON 46 PAL', Expected 2-Digit: 30, Predicted: 84, Expected 4-Digit: 3004, Predicted: 841122
# Run 7, Index: 109, Input Description: 'AUTOMOTIVE SPARE HS CODE 87085099', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 283200
# Run 7, Index: 43, Input Description: 'HYGIENE PRODUCTS HS CODE 39259010', Expected 2-Digit: 39, Predicted: 22, Expected 4-Digit: 3925, Predicted: 220410
# Run 7, Index: 39, Input Description: '900 SACK FECULA DE PAPA GRADO ALIMENTICIO POTATO STARCH SUPERIOR PALLETIZED TAX ID HME 660303531 HS CODE 11081300', Expected 2-Digit: 11, Predicted: 73, Expected 4-Digit: 1108, Predicted: 731990
# Run 7, Index: 146, Input Description: 'GALVANIZED STEEL STRAND HS CODE 7312.10.65', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7312, Predicted: 721700
# Run 7, Index: 127, Input Description: 'OF PHARMACEUTICAL GOODS ALL PACKED ONTO 37 PALLETS AVAMYS 2A NASAL SPRAY 005%120SPRHS CODE30043200 T', Expected 2-Digit: 30, Predicted: 85, Expected 4-Digit: 3004, Predicted: 854190
# Run 7, Index: 12, Input Description: 'PLASTIC ARTICLES HS CODE 392490', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3924, Predicted: 490800
# Run 7, Index: 214, Input Description: 'PAPER  HS CODE 4810 1300 ORDER 2218076NCM CODES 4810 1300', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4810, Predicted: 370300
# Run 7, Index: 153, Input Description: 'STEERING COMPONENTS FOR AUTOMOBILES HS CODE 870894 THYSSENKRUPP DELIVERY NOTE 82679385 82679386 82679387', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 848190
# Run 7, Index: 197, Input Description: 'JOINING STATION WITH UKS X296 INJECTION MOULDING TOOL X296 HS CODE 84779010 84807100', Expected 2-Digit: 84, Predicted: 96, Expected 4-Digit: 8477, Predicted: 960810
# Run 7, Index: 111, Input Description: 'HACOFLEX 3405 HS CODE 39199080', Expected 2-Digit: 39, Predicted: 10, Expected 4-Digit: 3919, Predicted: 100400
# Run 7, Index: 94, Input Description: 'COSMETICOS Y ARTICULOS DE PELUQUERIA (BEAUTY SUPPLIES) HS CODE 330590 IMO 2.1 ONU 1950 IMO 3 ONU 1993', Expected 2-Digit: 33, Predicted: 85, Expected 4-Digit: 3305, Predicted: 854231
# Run 7, Index: 44, Input Description: '1X20DC. SAID TO CONTAIN 21 PKGS IRON STEEL IRON AND STEEL ARTICLES METAL 72285020 HS BRIGHT BARS HOT ROLLED STAINLESS FERRITE 1.4104 CORRODUR 4104 X 14 CRMOS 17 HOT ROLLED PEELED TOL. ISO H9 OF CONTINUOUS CAST HS CODE 72222039', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7222, Predicted: 721300
# Run 7, Index: 205, Input Description: 'VOLVO RELATED BUSPARTS HS CODE 87089997  FREIGHT PREPAD 1 FAX 52 55 64 37 07 VAT VIM010810 5N3 ADMCD', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 841122
# Run 7, Index: 0, Input Description: 'CERAMIC TABLEWARE 26 PALL ETS 192 BOXES 2688 BOXE S HS CODE 6912.00', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6912, Predicted: 270120
# Run 7, Index: 107, Input Description: 'PAPERBOARD MATERIAL CODE R1627-618 HS CODE 48109230', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 7, Index: 195, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406', Expected 2-Digit: 94, Predicted: 54, Expected 4-Digit: 9406, Predicted: 540720
# Run 7, Index: 170, Input Description: 'LAMINATE FLOORING HS CODE  44111390PO 110914LAMINATE FLOORING HS CODE  44111390PO 110914LAMINATE FLOORING HS CODE  44111390PO 110914LAMINATE FLOORING HS CODE  44111390PO 110914LAMINATE FLOORING HS CODE  44111390PO 110914DETENTION AND DEMURRAGE APPLIE', Expected 2-Digit: 44, Predicted: 25, Expected 4-Digit: 4411, Predicted: 250900
# Run 7, Index: 181, Input Description: 'RING-GEAR PREF(INSTALLATION IN CARS) M0031939-40 M0032414-40 HS CODE 87085099', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 848210
# Run 7, Index: 110, Input Description: 'ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS CODE  39239099ON 46 PALLETSGILLETTE TRAY WIP 525 1HS', Expected 2-Digit: 39, Predicted: 01, Expected 4-Digit: 3923, Predicted: 010000
# Run 7, Index: 8, Input Description: 'STEERING COMPONENTS FOR AUTOMOBILES HS CODE 870894 THYSSENKRUPP DELIVERY NOTE 82679377 82679376 82679378 82679379 82679380 82679381 82679382 82679383 82679384', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 841122
# ...
# Run 8, Index: 184, Input Description: 'OF PHARMACEUTICAL GOODS ALL PACKED ONTO 36 PALLETS TRELEGY ELLIPTA 10062.525MCG 30DMX RELVARE 10025MCG 30DMXRELVARE 10025MCG 30 HS CODE 30043200', Expected 2-Digit: 30, Predicted: 30, Expected 4-Digit: 3004, Predicted: 300610
# Run 8, Index: 85, Input Description: 'PLASTIC BOTTLES AND CLOSURES FOR PLASTIC BOTTLES INVOICE 14489981448999 HS CODE 39233010 39235010', Expected 2-Digit: 39, Predicted: 49, Expected 4-Digit: 3923, Predicted: 490800
# Run 8, Index: 207, Input Description: '520 CARTONS LS-STRIP HS CODE 39201025', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3920, Predicted: 841122
# Run 8, Index: 89, Input Description: '2965 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 8, Index: 8, Input Description: 'STEERING COMPONENTS FOR AUTOMOBILES HS CODE 870894 THYSSENKRUPP DELIVERY NOTE 82679377 82679376 82679378 82679379 82679380 82679381 82679382 82679383 82679384', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 841122
# Run 8, Index: 111, Input Description: 'HACOFLEX 3405 HS CODE 39199080', Expected 2-Digit: 39, Predicted: 10, Expected 4-Digit: 3919, Predicted: 100400
# Run 8, Index: 180, Input Description: 'RING-GEAR PREF INSTALLATION IN CAR M0031939-40 M0032414-40 HS CODE 87085099', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 848210
# Run 8, Index: 174, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406 902480', Expected 2-Digit: 94, Predicted: 54, Expected 4-Digit: 9406, Predicted: 540720
# Run 8, Index: 18, Input Description: '42 PKGS RACK AND PINION ELECTRIC STEERING HS CODE 8708 9435', Expected 2-Digit: 87, Predicted: 86, Expected 4-Digit: 8708, Predicted: 860210
# Run 8, Index: 36, Input Description: '5 EXP WOOD FIBER BOARDS NCM 4411.13.10 HS CODE 4411.13 INVOICE EXP 130121 FREIGHT PREPAID DUE 21BR000481683-6 RUC 1BR76518836200000000000000', Expected 2-Digit: 44, Predicted: 44, Expected 4-Digit: 4411, Predicted: 440500
# Run 9, Index: 65, Input Description: 'STEEL FIBRES HS CODE 7205.21', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7205, Predicted: 721700
# Run 9, Index: 6, Input Description: 'STEEL BARS HS CODE 721510', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7215, Predicted: 721700
# Run 9, Index: 109, Input Description: 'AUTOMOTIVE SPARE HS CODE 87085099', Expected 2-Digit: 87, Predicted: 28, Expected 4-Digit: 8708, Predicted: 283200
# Run 9, Index: 199, Input Description: ' ALIMENTARY SAUCES HS CODE 2103', Expected 2-Digit: 21, Predicted: 28, Expected 4-Digit: 2103, Predicted: 284030
# Run 9, Index: 90, Input Description: 'HOUSEHOLD GOODS MADE OF ALUMINIUM OR PLASTIC HS CODE 39249000', Expected 2-Digit: 39, Predicted: 56, Expected 4-Digit: 3924, Predicted: 560890
# Run 9, Index: 142, Input Description: 'LAMINATE FLOORING HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 9, Index: 53, Input Description: 'OFFICE CHAIRS AND PARTS  HS CODE 9401 9080 7320 20817318 1568 7318 1290 6006 3200 6005 3700 5903 209', Expected 2-Digit: 94, Predicted: 69, Expected 4-Digit: 9401, Predicted: 691000
# Run 9, Index: 23, Input Description: 'SMLS STEEL PIPES HS CODE 73043992 1737 PCS; 281232 8222 KG NETKG BRUT', Expected 2-Digit: 73, Predicted: 72, Expected 4-Digit: 7304, Predicted: 721700
# Run 9, Index: 106, Input Description: '5X40HR SAID TO CONTAIN 212 ROLLS PLATES SHEETS FILM FOIL PLASTIC APET PLASTICS SHEET IN ROLL FORM HS CODE392062 TAX ID PLA130417ED5 FREIGHT PREPAID TEL52 55 5822 8000 E MAILANB WOW.COM.MX', Expected 2-Digit: 39, Predicted: 44, Expected 4-Digit: 3920, Predicted: 441300
# Run 9, Index: 60, Input Description: '01 X 20 FCL SAID TO CONTA IN 24 PALLETS ONLY 24 PAL LETS OF AUTOMOBILE SPARES CYLINDER LINERS HS CODE 84099949 INVOICE NO.41202 1-22 DT.05.06.2021 SBILL NO 2253361 DATE 07.06.20 21 REF PO NO. MAR.20-21 2 021-22 DT.15.04.2021 NET W EIGHT 163', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8409, Predicted: 840733
# Run 9, Index: 36, Input Description: '5 EXP WOOD FIBER BOARDS NCM 4411.13.10 HS CODE 4411.13 INVOICE EXP 130121 FREIGHT PREPAID DUE 21BR000481683-6 RUC 1BR76518836200000000000000', Expected 2-Digit: 44, Predicted: 44, Expected 4-Digit: 4411, Predicted: 440500
# Run 9, Index: 149, Input Description: 'SODIUM LIGNOSULPHONATE LIGNOSULPHONATE DOMSJOE LIGNIN DS 10 TOTAL 400 BIG BAGS NET WEIGHT 240000 KGS GROSS WEIGHT 244000 KGS HS CODE 38040000', Expected 2-Digit: 38, Predicted: 28, Expected 4-Digit: 3804, Predicted: 283210
# Run 9, Index: 175, Input Description: '1 UNIT FLOUR MILL CONVEYIN G MACHINERY AND EQUIPMENT AT THE DISMANTLED STATE PNEUMATIC CONVEYING GRAIN IMPURITIES SYSTEM WITH AC CESSORIES TO NORMAL OPERA TION HS CODE 8437.80', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8437, Predicted: 843610
# Run 9, Index: 24, Input Description: '7X40DC. 5X40HC. SAID TO CONTAIN 264 SKIDS THERMOFORMED TRAYS HS CODE 39239000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3923, Predicted: 842699
# Run 9, Index: 83, Input Description: '2987 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 9, Index: 208, Input Description: 'CONNECTORS HS CODE 853890 15630532046', Expected 2-Digit: 85, Predicted: 84, Expected 4-Digit: 8538, Predicted: 841122
# Run 9, Index: 88, Input Description: 'PLASTIC PROFILES  HS CODE 3916 9050 7326 2000  NCM CODES 3916 9050 7326 2000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3916, Predicted: 841000
# Run 9, Index: 51, Input Description: 'FREIGHT COLLECTCERAMIC TILES SAMPLESHS CODE 690721', Expected 2-Digit: 69, Predicted: 08, Expected 4-Digit: 6907, Predicted: 080610
# Run 9, Index: 89, Input Description: '2965 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 9, Index: 137, Input Description: '1X20DC. SAID TO CONTAIN 132 PIECES PLASTIC PLASTIC ARTICLES NEW MSKU5916711 20 DRY 86 SHIPPERS SEAL 1475532 132 PIECES GROSS WEIGHT 1715.00 KGS MEASUREMENT 16.474 CBM BEIERSDORF PRODUCTS 132 BOXES ON 11 PALLETSF INVOICE NO. 250709 HS CODE 39235010 MA', Expected 2-Digit: 39, Predicted: 89, Expected 4-Digit: 3923, Predicted: 890130
# Run 9, Index: 158, Input Description: 'VOLVO RELATED BUSPARTS HS CODE 87089997  FREIGHT PREPAID 1 TEL 52 55 50903871 FAX 52 55 64 37 07 VAT', Expected 2-Digit: 87, Predicted: 84, Expected 4-Digit: 8708, Predicted: 841122
# Run 9, Index: 86, Input Description: 'PLASTIC PACKING MATERIALS 21 PALLETS HS CODE 392330', Expected 2-Digit: 39, Predicted: 97, Expected 4-Digit: 3923, Predicted: 970300
# Run 9, Index: 143, Input Description: 'AUTOMOTIVE SPARE HS CODE 87089997', Expected 2-Digit: 87, Predicted: 85, Expected 4-Digit: 8708, Predicted: 850433
# Run 9, Index: 209, Input Description: 'ALUMINIUM BILLET ALLOY 606 3IN 8 HS CODE 7601 20 COUNTRY OF ORIGIN INDIA TOTAL GROSS WT MT 306.67 5 TOTAL NET WT MT 305.44 6 TOTAL BUNDLES 120 TOTA L PIECES 600 SHIPPING BI LL NO 4000174 SHIPPING BI LL DATE 22 01 2021 14 DA YS FREE T', Expected 2-Digit: 76, Predicted: 73, Expected 4-Digit: 7601, Predicted: 730630
# Run 9, Index: 25, Input Description: 'PULLEY W P L 92HITACHION 44 PALLETSAUTOMOTIVEHS CODE  848350SANTA ROSA  MXPLANT 3DELIVERY NOTE80330838PULLEY W P L 92HITACHIPULLEY W P GENS   V8 1 AUTOMOTIVEON 44 PALLETSSANTA ROSA  MXHS CODE  848350PLANT 3DELIVERY NOTETOTAL PKGS 88 PK803308378033083', Expected 2-Digit: 84, Predicted: 85, Expected 4-Digit: 8483, Predicted: 850239
# Run 9, Index: 201, Input Description: 'STEEL BARS HS CODE 72283061', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7228, Predicted: 721700
# Run 9, Index: 68, Input Description: 'PIECES AND SPARE PARTS FOR PREFABRICATED CONSTRUCTIONS HS CODE 9406 FREIGHT PREPAIDSHIPPED ON BOARD T 52 55 47507100', Expected 2-Digit: 94, Predicted: 10, Expected 4-Digit: 9406, Predicted: 100200
# Run 9, Index: 187, Input Description: 'COLD ROLLED STAINLESS STEEL COILS 1 4301   304PL 42149004 42149005 42149015 42149016HS CODE  72202081 72202041 72193510ORDER NO  S O 1000385746  1000386810  1000392536 1000392537GROSS NET WEIGHT  17668 16802 KGS  CONTACT PHONE   52 442 659 5459FREIGH', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7220, Predicted: 721300
# Run 9, Index: 81, Input Description: 'CERAMIC TILES AND SAMPLES 17 PALLETS HS CODE 690723', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6907, Predicted: 270120
# Run 9, Index: 30, Input Description: '48 AUTOMOTIVE PARTS HS CODE 87081090', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 10, Index: 198, Input Description: 'WASTE PAPER SORTED WHITE LEDGER HS CODE4707200000', Expected 2-Digit: 47, Predicted: 47, Expected 4-Digit: 4707, Predicted: 470700
# Run 10, Index: 107, Input Description: 'PAPERBOARD MATERIAL CODE R1627-618 HS CODE 48109230', Expected 2-Digit: 48, Predicted: 48, Expected 4-Digit: 4810, Predicted: 481730
# Run 10, Index: 172, Input Description: 'PARTS SUITABLE FOR USE SOL ELY OR PRINCIPALLY WITH TH E ENGINES OF HEADING 8407 OR 8408 CYLINDER LINERS HS CODE 84099941 TOTAL NO O F CYLINDERS 20794 TOTAL N O OF PALLETS 44 INVOICE N O 14004239 DATE 28.05.2 021 SHIPPING BILL NO 4001 272 DATE', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8409, Predicted: 840734
# Run 10, Index: 41, Input Description: '24040430 LITERS 0820920 LA MADRILE A CREAM LIQUEUR CONCENTRATE NON HAZARDOUS HS CODE 210690 SEALSCC3', Expected 2-Digit: 21, Predicted: 72, Expected 4-Digit: 2106, Predicted: 721300
# Run 10, Index: 7, Input Description: 'SODIUM BISULFATE 960X25 KG PE BAGS ON 20 PALLETS NET 24.000 KG HS CODE 283319', Expected 2-Digit: 28, Predicted: 28, Expected 4-Digit: 2833, Predicted: 283210
# Run 10, Index: 128, Input Description: 'FORKLIFT TRUCKS HS CODE 842720 PO 4500197904', Expected 2-Digit: 84, Predicted: 84, Expected 4-Digit: 8427, Predicted: 841122
# Run 10, Index: 152, Input Description: 'CONTAINING 231 CARTONS  SOAP BASE HS CODE 3402190 FREIGHT PREPAID NCM CODES 3402190', Expected 2-Digit: 34, Predicted: 83, Expected 4-Digit: 3402, Predicted: 830621
# Run 10, Index: 22, Input Description: 'PLASTIC PROFILES  HS CODE 3916 1000 3916 90507326 2000   NCM CODES 3916 9050 7326 2000', Expected 2-Digit: 39, Predicted: 84, Expected 4-Digit: 3916, Predicted: 841000
# Run 10, Index: 197, Input Description: 'JOINING STATION WITH UKS X296 INJECTION MOULDING TOOL X296 HS CODE 84779010 84807100', Expected 2-Digit: 84, Predicted: 96, Expected 4-Digit: 8477, Predicted: 960810
# Run 10, Index: 83, Input Description: '2987 AUTOMOTIVE PARTS HS CODE 87089299', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 10, Index: 30, Input Description: '48 AUTOMOTIVE PARTS HS CODE 87081090', Expected 2-Digit: 87, Predicted: 93, Expected 4-Digit: 8708, Predicted: 930320
# Run 10, Index: 210, Input Description: 'TEJIDOS DE ALGODON CON POLIESTER COTTON FABRIC WITH POLYESTER HS CODE 521139 OUR HBL NR BCNVERL00060', Expected 2-Digit: 52, Predicted: 55, Expected 4-Digit: 5211, Predicted: 551600
# Run 10, Index: 138, Input Description: 'NEW AUTOMOTIVE PARTS HS CODE 87089499', Expected 2-Digit: 87, Predicted: 69, Expected 4-Digit: 8708, Predicted: 691010
# Run 10, Index: 63, Input Description: 'ROHS CONNECTOR + PRINTED   CURCUIT BOARD    HS CODE 85366990 &    85340090  CN> 76046 MEXICO', Expected 2-Digit: 85, Predicted: 84, Expected 4-Digit: 8536, Predicted: 846592
# Run 10, Index: 139, Input Description: 'SPIRITS HS CODE 2208  NCM CODES 220870', Expected 2-Digit: 22, Predicted: 28, Expected 4-Digit: 2208, Predicted: 283630
# Run 10, Index: 37, Input Description: '1X40HC. SAID TO CONTAIN 21 PACKAGES ELECTRICAL EQUIPMENTS  ORDERCS01009590 INVOICE9143892199 HS CODE85353010 ELECTRONICS ELECTRONIC APPLIANCES AUDIO VIDEO EQUIPMENT TELECOMMUNICATION EQUIPMENT NEW', Expected 2-Digit: 85, Predicted: 85, Expected 4-Digit: 8535, Predicted: 851621
# Run 10, Index: 127, Input Description: 'OF PHARMACEUTICAL GOODS ALL PACKED ONTO 37 PALLETS AVAMYS 2A NASAL SPRAY 005%120SPRHS CODE30043200 T', Expected 2-Digit: 30, Predicted: 85, Expected 4-Digit: 3004, Predicted: 854190
# Run 10, Index: 4, Input Description: 'CIGARETTES SO 10217102461021742687 HS CODE 2402.20.90', Expected 2-Digit: 24, Predicted: 63, Expected 4-Digit: 2402, Predicted: 630200
# Run 10, Index: 1, Input Description: 'TOTAL 5040 BOXES ONLY TOTA L FIVE THOUSAND FOURTY BOX ES ONLY TOTAL 5040 BOXES P ACKED ON 92 PALLETS. POLIS HED PORCELAIN TILES SOL UBLE SALT TILES SIZE 6 00X1200MM HS CODE 6907210 0 TOTAL NET WEIGHT 107 680.00 KGS FREIGHT COLLEC T ONC C', Expected 2-Digit: 69, Predicted: 28, Expected 4-Digit: 6907, Predicted: 283400
# Run 10, Index: 120, Input Description: '05 X 40 HC CONTAINERS CONTAINING90 BUNDLESCONTAININGCOMMERCIAL PINEPLYWOOD C  CRUC 1BR086321732FREITAS0000000MPW0477IENCM  4412 39 00WOODEN PACKAGE TREATED AND CERTIFIEDHS CODE  4412 39 00MRUC  1BR09412398200000000000000000121821  PH  5511 31207002', Expected 2-Digit: 44, Predicted: 09, Expected 4-Digit: 4412, Predicted: 091091
# Run 10, Index: 48, Input Description: 'SUBMERSIBLE PUMP HS CODE 84139100', Expected 2-Digit: 84, Predicted: 28, Expected 4-Digit: 8413, Predicted: 283330
# Run 10, Index: 59, Input Description: '1X20DC. SAID TO CONTAIN 24 COLLIS CITRIC ACID ANHYDROUS F5020 HS CODE 291814', Expected 2-Digit: 29, Predicted: 28, Expected 4-Digit: 2918, Predicted: 280700
# Run 10, Index: 206, Input Description: '2X20 FCL CONTAINER SAID T O CONTAIN TOTAL 1750 BOXES ONLY TOTAL ONE THOUSAND S EVEN HUNDRED FIFTY BOXES O NLY 1750 BOXES PACKED IN 3 0 PALLETS GLAZED PORCELAIN TILES PACKED IN 15 PALLET S HS CODE 69072100 TOTAL NET WEIGHT 53300.00 KGS F REIGHT CO', Expected 2-Digit: 69, Predicted: 26, Expected 4-Digit: 6907, Predicted: 260200
# Run 10, Index: 25, Input Description: 'PULLEY W P L 92HITACHION 44 PALLETSAUTOMOTIVEHS CODE  848350SANTA ROSA  MXPLANT 3DELIVERY NOTE80330838PULLEY W P L 92HITACHIPULLEY W P GENS   V8 1 AUTOMOTIVEON 44 PALLETSSANTA ROSA  MXHS CODE  848350PLANT 3DELIVERY NOTETOTAL PKGS 88 PK803308378033083', Expected 2-Digit: 84, Predicted: 85, Expected 4-Digit: 8483, Predicted: 850239
# Run 10, Index: 186, Input Description: '5 EXP WOOD FIBER BOARDS NCM 4411.13.10 HS CODE 4411.13 INVOICE EXP 207221 FREIGHT PREPAID DU-E 21BR000831515-7 RUC 1BR76518836200000000000', Expected 2-Digit: 44, Predicted: 44, Expected 4-Digit: 4411, Predicted: 440500
# Run 10, Index: 141, Input Description: 'FREIGHT PREPAIDAUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810AUTOMOTIVE CARGOPARTE PARA EJE CARDANHS CODE 870810', Expected 2-Digit: 87, Predicted: 58, Expected 4-Digit: 8708, Predicted: 581000
# Run 10, Index: 5, Input Description: '20 TWENTY BOXES ONLY CON TAINING MILD STEEL MIG WIR E HS CODE 72173020 INVOIC E NO. EXP21-22073 DT 05 042021 SBILL NO. 15881 13 DT. 05052021 IEC CODE - 0504047655 NET WEIGHT 20640.00 KGS', Expected 2-Digit: 72, Predicted: 72, Expected 4-Digit: 7217, Predicted: 721700
# Run 10, Index: 142, Input Description: 'LAMINATE FLOORING HS CODE 44111390', Expected 2-Digit: 44, Predicted: 49, Expected 4-Digit: 4411, Predicted: 490810
# Run 10, Index: 81, Input Description: 'CERAMIC TILES AND SAMPLES 17 PALLETS HS CODE 690723', Expected 2-Digit: 69, Predicted: 27, Expected 4-Digit: 6907, Predicted: 270120
# Run 10, Index: 190, Input Description: 'PAPER TOTAL 175 REELS PERFORMANCE WHITE SE WHITE SACK PAPER HS CODE 48042910 ORDER REF 743265 CIF VERACRUZ INCOTERMS 2020', Expected 2-Digit: 48, Predicted: 37, Expected 4-Digit: 4804, Predicted: 370300
# [0.26666666666666666, 0.3, 0.1, 0.13333333333333333, 0.2, 0.16666666666666666, 0.06666666666666667, 0.13333333333333333, 0.23333333333333334, 0.26666666666666666]
# [0.06666666666666667, 0.0, 0.0, 0.0, 0.03333333333333333, 0.0, 0.0, 0.0, 0.0, 0.06666666666666667]
